# %%
import pandas as pd

df = pd.read_csv("dataset_clientes.csv")
df.head()
# Out:
#    id_cliente             nome genero  idade          cidade data_cadastro  \
# 0           1        Ana Souza      F     28       São Paulo    2023-01-10
# 1           2       Lucas Lima      M     35  Rio de Janeiro    2023-02-15
# 2           3    Mariana Alves      F     22  Belo Horizonte    2023-03-20
# 3           4    Carlos Mendes      M     40        Curitiba    2023-04-01
# 4           5  Julia Fernandes      F     30    Porto Alegre    2023-05-05
#
#    valor_total       categoria data_pedido
# 0          250   Moda Feminina  2024-01-12
# 1          420  Moda Masculina  2024-02-02
# 2          180      Acessórios  2024-02-18
# 3          600  Moda Masculina  2024-03-10
# 4          350   Moda Feminina  2024-03-15
